# %%
import statsapi
import pandas as pd
from pandas import Series, DataFrame

# %%
# Given dictionary
data = statsapi.player_stat_data(statsapi.lookup_player('ohtani, shohei')[0]['id'], group="pitching", type="yearByYear", sportId=1)

# Flatten the dictionary and extract stats for each season
player_stats = []
for season_stats in data['stats']:
    season_data = season_stats['stats']
    season_data['season'] = season_stats['season']
    player_stats.append(season_data)

# Create DataFrame from the list of dictionaries
ohtani_df = pd.DataFrame(player_stats)

# Display DataFrame
ohtani_df
# Out:
#    gamesPlayed  gamesStarted  groundOuts  airOuts  runs  doubles  triples  \
# 0           10            10          37       50    19        6        0
# 1            2             2           0        2     7        0        0
# 2           23            23         113      112    48       23        0
# 3           28            28         129      141    45       23        2
# 4           23            23         114       98    50       15        0
#
#    homeRuns  strikeOuts  baseOnBalls  ...  walksPer9Inn  hitsPer9Inn  \
# 0         6          63           22  ...          3.83         6.62
# 1         0           3            8  ...         43.20        16.20
# 2        15         156           44  ...          3.04         6.77
# 3        14         219           44  ...          2.39         6.72
# 4        18         167           55  ...          3.75         5.80
#
#    runsScoredPer9 homeRunsPer9  inheritedRunners inheritedRunnersScored  \
# ...

# %%
# Column to move to the front
column_to_move = 'season'

# Extract the column
column = ohtani_df[column_to_move]

# Drop the column from its original position
ohtani_df.drop(columns=[column_to_move], inplace=True)

# Insert the column at the front
ohtani_df.insert(0, column_to_move, column)

ohtani_df.insert(0, 'name', 'Shohei Ohtani')

# Display the DataFrame
ohtani_df
# Out:
#             name season  gamesPlayed  gamesStarted  groundOuts  airOuts  runs  \
# 0  Shohei Ohtani   2018           10            10          37       50    19
# 1  Shohei Ohtani   2020            2             2           0        2     7
# 2  Shohei Ohtani   2021           23            23         113      112    48
# 3  Shohei Ohtani   2022           28            28         129      141    45
# 4  Shohei Ohtani   2023           23            23         114       98    50
#
#    doubles  triples  homeRuns  ...  strikeoutsPer9Inn  walksPer9Inn  \
# 0        6        0         6  ...              10.97          3.83
# 1        0        0         0  ...              16.20         43.20
# 2       23        0        15  ...              10.77          3.04
# 3       23        2        14  ...              11.87          2.39
# 4       15        0        18  ...              11.39          3.75
#
#    hitsPer9Inn  runsScoredPer9  homeRunsPer9 inheritedRunners  \
# ...

# %%
columns_to_keep = ['name', 'season', 'gamesStarted', 'wins', 'losses', 'inningsPitched', 'era', 'earnedRuns', 'avg', 'ops', 'whip', 'strikeOuts', 'strikeoutWalkRatio', 'totalBases', 'walksPer9Inn', 'hitsPer9Inn', 'runsScoredPer9']
ohtani_pitch = ohtani_df.loc[:, columns_to_keep]
ohtani_pitch
# Out:
#             name season  gamesStarted  wins  losses inningsPitched    era  \
# 0  Shohei Ohtani   2018            10     4       2           51.2   3.31
# 1  Shohei Ohtani   2020             2     0       1            1.2  37.80
# 2  Shohei Ohtani   2021            23     9       2          130.1   3.18
# 3  Shohei Ohtani   2022            28    15       9          166.0   2.33
# 4  Shohei Ohtani   2023            23    10       5          132.0   3.14
#
#    earnedRuns   avg    ops  whip  strikeOuts strikeoutWalkRatio  totalBases  \
# 0          19  .203   .621  1.16          63               2.86          62
# 1           7  .375  1.063  6.60           3               0.38           3
# 2          46  .207   .637  1.09         156               3.55         166
# 3          43  .203   .574  1.01         219               4.98         193
# 4          46  .184   .618  1.06         167               3.04         154
#
#   walksPer9Inn hitsPer9Inn runsScoredPer9
# ...

# %%
ohtani_pitch_comp = ohtani_pitch[ohtani_pitch['season'] == '2022']
ohtani_pitch_comp
# Out:
#             name season  gamesStarted  wins  losses inningsPitched   era  \
# 3  Shohei Ohtani   2022            28    15       9          166.0  2.33
#
#    earnedRuns   avg   ops  whip  strikeOuts strikeoutWalkRatio  totalBases  \
# 3          43  .203  .574  1.01         219               4.98         193
#
#   walksPer9Inn hitsPer9Inn runsScoredPer9
# 3         2.39        6.72           2.44

# %%
# Given dictionary
data = statsapi.player_stat_data(statsapi.lookup_player('cole, gerrit')[0]['id'], group="pitching", type="yearByYear", sportId=1)

# Flatten the dictionary and extract stats for each season
player_stats = []
for season_stats in data['stats']:
    season_data = season_stats['stats']
    season_data['season'] = season_stats['season']
    player_stats.append(season_data)

# Create DataFrame from the list of dictionaries
cole_df = pd.DataFrame(player_stats)

# Display DataFrame
cole_df
# Out:
#     gamesPlayed  gamesStarted  groundOuts  airOuts  runs  doubles  triples  \
# 0            19            19         137       92    43       15        0
# 1            22            22         151      106    58       24        5
# 2            32            32         224      169    71       31        5
# 3            21            21         130      105    57       32        1
# 4            33            33         217      178    98       36        6
# 5            32            32         124      185    68       36        2
# 6            33            33         134      164    66       30        1
# 7            12            12          53       69    27       14        0
# 8            30            30         138      151    69       27        1
# 9            33            33         165      164    81       31        2
# 10           33            33         173      213    64       26        1
#
# ...

# %%
# Column to move to the front
column_to_move = 'season'

# Extract the column
column = cole_df[column_to_move]

# Drop the column from its original position
cole_df.drop(columns=[column_to_move], inplace=True)

# Insert the column at the front
cole_df.insert(0, column_to_move, column)

cole_df.insert(0, 'name', 'Gerrit Cole')

# Display the DataFrame
cole_df
# Out:
#            name season  gamesPlayed  gamesStarted  groundOuts  airOuts  runs  \
# 0   Gerrit Cole   2013           19            19         137       92    43
# 1   Gerrit Cole   2014           22            22         151      106    58
# 2   Gerrit Cole   2015           32            32         224      169    71
# 3   Gerrit Cole   2016           21            21         130      105    57
# 4   Gerrit Cole   2017           33            33         217      178    98
# 5   Gerrit Cole   2018           32            32         124      185    68
# 6   Gerrit Cole   2019           33            33         134      164    66
# 7   Gerrit Cole   2020           12            12          53       69    27
# 8   Gerrit Cole   2021           30            30         138      151    69
# 9   Gerrit Cole   2022           33            33         165      164    81
# 10  Gerrit Cole   2023           33            33         173      213    64
#
# ...

# %%
cole_pitch = cole_df.loc[:, columns_to_keep]
cole_pitch
# Out:
#            name season  gamesStarted  wins  losses inningsPitched   era  \
# 0   Gerrit Cole   2013            19    10       7          117.1  3.22
# 1   Gerrit Cole   2014            22    11       5          138.0  3.65
# 2   Gerrit Cole   2015            32    19       8          208.0  2.60
# 3   Gerrit Cole   2016            21     7      10          116.0  3.88
# 4   Gerrit Cole   2017            33    12      12          203.0  4.26
# 5   Gerrit Cole   2018            32    15       5          200.1  2.88
# 6   Gerrit Cole   2019            33    20       5          212.1  2.50
# 7   Gerrit Cole   2020            12     7       3           73.0  2.84
# 8   Gerrit Cole   2021            30    16       8          181.1  3.23
# 9   Gerrit Cole   2022            33    13       8          200.2  3.50
# 10  Gerrit Cole   2023            33    15       4          209.0  2.63
#
#     earnedRuns   avg   ops  whip  strikeOuts strikeoutWalkRatio  totalBases  \
# ...

# %%
cole_pitch_comp = cole_pitch[cole_pitch['season'] == '2023']
cole_pitch_comp
# Out:
#            name season  gamesStarted  wins  losses inningsPitched   era  \
# 10  Gerrit Cole   2023            33    15       4          209.0  2.63
#
#     earnedRuns   avg   ops  whip  strikeOuts strikeoutWalkRatio  totalBases  \
# 10          61  .206  .581  0.98         222               4.63         245
#
#    walksPer9Inn hitsPer9Inn runsScoredPer9
# 10         2.07        6.76           2.76

# %%
ohtani_pitch_comp = pd.concat([ohtani_pitch_comp, cole_pitch_comp], ignore_index=True)
ohtani_pitch_comp
# Out:
#             name season  gamesStarted  wins  losses inningsPitched   era  \
# 0  Shohei Ohtani   2022            28    15       9          166.0  2.33
# 1    Gerrit Cole   2023            33    15       4          209.0  2.63
#
#    earnedRuns   avg   ops  whip  strikeOuts strikeoutWalkRatio  totalBases  \
# 0          43  .203  .574  1.01         219               4.98         193
# 1          61  .206  .581  0.98         222               4.63         245
#
#   walksPer9Inn hitsPer9Inn runsScoredPer9
# 0         2.39        6.72           2.44
# 1         2.07        6.76           2.76

# %%
# Given dictionary
data = statsapi.player_stat_data(statsapi.lookup_player('verlander, justin')[0]['id'], group="pitching", type="yearByYear", sportId=1)

# Flatten the dictionary and extract stats for each season
player_stats = []
for season_stats in data['stats']:
    season_data = season_stats['stats']
    season_data['season'] = season_stats['season']
    player_stats.append(season_data)

# Create DataFrame from the list of dictionaries
verlander_df = pd.DataFrame(player_stats)

# Display DataFrame
verlander_df
# Out:
#     gamesPlayed  gamesStarted  groundOuts  airOuts  runs  doubles  triples  \
# 0             2             2          15       11     9        5        0
# 1            30            30         195      203    78       33        4
# 2            32            32         186      230    88       33        2
# 3            33            33         182      239   119       39        1
# 4            35            35         172      252    99       50        2
# 5            33            33         205      234    89       37        7
# 6            34            34         215      270    73       31        3
# 7            33            33         230      230    81       40        2
# 8            34            34         176      241    94       38        4
# 9            32            32         186      255   114       51        9
# 10           20            20          99      175    56       20        2
# ...

# %%
# Column to move to the front
column_to_move = 'season'

# Extract the column
column = verlander_df[column_to_move]

# Drop the column from its original position
verlander_df.drop(columns=[column_to_move], inplace=True)

# Insert the column at the front
verlander_df.insert(0, column_to_move, column)

verlander_df.insert(0, 'name', 'Justin Verlander')

verlander_pitch = verlander_df.loc[:, columns_to_keep]

verlander_pitch_comp = verlander_pitch[verlander_pitch['season'] == '2022']
verlander_pitch_comp
# Out:
#                 name season  gamesStarted  wins  losses inningsPitched   era  \
# 18  Justin Verlander   2022            28    18       4          175.0  1.75
#
#     earnedRuns   avg   ops  whip  strikeOuts strikeoutWalkRatio  totalBases  \
# 18          34  .186  .497  0.83         185               6.38         169
#
#    walksPer9Inn hitsPer9Inn runsScoredPer9
# 18         1.49        5.97           2.21

# %%
ohtani_pitch_comp = pd.concat([ohtani_pitch_comp, verlander_pitch_comp], ignore_index=True)
ohtani_pitch_comp
# Out:
#                name season  gamesStarted  wins  losses inningsPitched   era  \
# 0     Shohei Ohtani   2022            28    15       9          166.0  2.33
# 1       Gerrit Cole   2023            33    15       4          209.0  2.63
# 2  Justin Verlander   2022            28    18       4          175.0  1.75
#
#    earnedRuns   avg   ops  whip  strikeOuts strikeoutWalkRatio  totalBases  \
# 0          43  .203  .574  1.01         219               4.98         193
# 1          61  .206  .581  0.98         222               4.63         245
# 2          34  .186  .497  0.83         185               6.38         169
#
#   walksPer9Inn hitsPer9Inn runsScoredPer9
# 0         2.39        6.72           2.44
# 1         2.07        6.76           2.76
# 2         1.49        5.97           2.21

# %%
# Given dictionary
data = statsapi.player_stat_data(592662, group="pitching", type="yearByYear", sportId=1)

# Flatten the dictionary and extract stats for each season
player_stats = []
for season_stats in data['stats']:
    season_data = season_stats['stats']
    season_data['season'] = season_stats['season']
    player_stats.append(season_data)

# Create DataFrame from the list of dictionaries
ray_df = pd.DataFrame(player_stats)

# Display DataFrame
ray_df
# Out:
#     gamesPlayed  gamesStarted  groundOuts  airOuts  runs  doubles  triples  \
# 0             9             6          28       35    26       13        1
# 1            23            23         123      125    56       30        6
# 2            32            32         162      134   105       32        5
# 3            28            28         114      141    57       18        2
# 4            24            24          93       96    55       16        0
# 5            33            33         132      140    91       33        5
# 6             7             7          12       36    27        9        0
# 7             5             4          14       22    13        5        0
# 8            12            11          26       58    40       14        0
# 9            32            32         133      186    62       31        3
# 10           32            32         151      180    80       29        5
# ...

# %%
# Column to move to the front
column_to_move = 'season'

# Extract the column
column = ray_df[column_to_move]

# Drop the column from its original position
ray_df.drop(columns=[column_to_move], inplace=True)

# Insert the column at the front
ray_df.insert(0, column_to_move, column)

ray_df.insert(0, 'name', 'Robbie Ray')

ray_pitch = ray_df.loc[:, columns_to_keep]

ray_pitch_comp = ray_pitch[ray_pitch['season'] == '2021']
ray_pitch_comp
# Out:
#          name season  gamesStarted  wins  losses inningsPitched   era  \
# 9  Robbie Ray   2021            32    13       7          193.1  2.84
#
#    earnedRuns   avg   ops  whip  strikeOuts strikeoutWalkRatio  totalBases  \
# 9          61  .210  .668  1.04         248               4.77         286
#
#   walksPer9Inn hitsPer9Inn runsScoredPer9
# 9         2.42        6.98           2.89

# %%
ohtani_pitch_comp = pd.concat([ohtani_pitch_comp, ray_pitch_comp], ignore_index=True)
ohtani_pitch_comp
# Out:
#                name season  gamesStarted  wins  losses inningsPitched   era  \
# 0     Shohei Ohtani   2022            28    15       9          166.0  2.33
# 1       Gerrit Cole   2023            33    15       4          209.0  2.63
# 2  Justin Verlander   2022            28    18       4          175.0  1.75
# 3        Robbie Ray   2021            32    13       7          193.1  2.84
#
#    earnedRuns   avg   ops  whip  strikeOuts strikeoutWalkRatio  totalBases  \
# 0          43  .203  .574  1.01         219               4.98         193
# 1          61  .206  .581  0.98         222               4.63         245
# 2          34  .186  .497  0.83         185               6.38         169
# 3          61  .210  .668  1.04         248               4.77         286
#
#   walksPer9Inn hitsPer9Inn runsScoredPer9
# 0         2.39        6.72           2.44
# 1         2.07        6.76           2.76
# 2         1.49        5.97           2.21
# ...

# %%
ohtani_pitch_comp.transpose()
# Out:
#                                 0            1                 2           3
# name                Shohei Ohtani  Gerrit Cole  Justin Verlander  Robbie Ray
# season                       2022         2023              2022        2021
# gamesStarted                   28           33                28          32
# wins                           15           15                18          13
# losses                          9            4                 4           7
# inningsPitched              166.0        209.0             175.0       193.1
# era                          2.33         2.63              1.75        2.84
# earnedRuns                     43           61                34          61
# avg                          .203         .206              .186        .210
# ops                          .574         .581              .497        .668
# whip                         1.01         0.98              0.83        1.04
# ...

# %%
# Given dictionary
data = statsapi.player_stat_data(statsapi.lookup_player('harper, bryce')[0]['id'], group="hitting", type="yearByYear", sportId=1)

# Flatten the dictionary and extract stats for each season
player_stats = []
for season_stats in data['stats']:
    season_data = season_stats['stats']
    season_data['season'] = season_stats['season']
    player_stats.append(season_data)

# Create DataFrame from the list of dictionaries
harper_df = pd.DataFrame(player_stats)

# Display DataFrame
harper_df
# Out:
#     gamesPlayed  groundOuts  airOuts  runs  doubles  triples  homeRuns  \
# 0           139         143      132    98       26        9        22
# 1           118         124       97    71       24        3        20
# 2           100          79       77    41       10        2        13
# 3           153         113      109   118       38        1        42
# 4           147         127      149    84       24        2        24
# 5           111          85      105    95       27        1        29
# 6           159         124      129   103       34        0        34
# 7           157         116      134    98       36        1        35
# 8            58          44       55    41        9        2        13
# 9           141         112       97   101       42        1        35
# 10           99          98       86    63       28        1        18
# 11          126         115       93    84       29        1        21
#
# ...

# %%
# Column to move to the front
column_to_move = 'season'

# Extract the column
column = harper_df[column_to_move]

# Drop the column from its original position
harper_df.drop(columns=[column_to_move], inplace=True)

# Insert the column at the front
harper_df.insert(0, column_to_move, column)

harper_df.insert(0, 'name', 'Bryce Harper')

# Display the DataFrame
harper_df
# Out:
#             name season  gamesPlayed  groundOuts  airOuts  runs  doubles  \
# 0   Bryce Harper   2012          139         143      132    98       26
# 1   Bryce Harper   2013          118         124       97    71       24
# 2   Bryce Harper   2014          100          79       77    41       10
# 3   Bryce Harper   2015          153         113      109   118       38
# 4   Bryce Harper   2016          147         127      149    84       24
# 5   Bryce Harper   2017          111          85      105    95       27
# 6   Bryce Harper   2018          159         124      129   103       34
# 7   Bryce Harper   2019          157         116      134    98       36
# 8   Bryce Harper   2020           58          44       55    41        9
# 9   Bryce Harper   2021          141         112       97   101       42
# 10  Bryce Harper   2022           99          98       86    63       28
# 11  Bryce Harper   2023          126         115       93    84       29
#
# ...

# %%
harper_df = harper_df[['name', 'season', 'gamesPlayed', 'avg', 'ops', 'homeRuns', 'runs', 'totalBases', 'rbi', 'babip']]
harper_df_comp = harper_df[harper_df['season'] == '2023']
harper_df_comp
# Out:
#             name season  gamesPlayed   avg   ops  homeRuns  runs  totalBases  \
# 11  Bryce Harper   2023          126  .293  .900        21    84         228
#
#     rbi babip
# 11   72  .352
