# %%
import statsapi
import pandas as pd
from pandas import Series, DataFrame

# %%
# Given dictionary
data = statsapi.player_stat_data(statsapi.lookup_player('ohtani, shohei')[0]['id'], group="hitting", type="yearByYear", sportId=1)

# Flatten the dictionary and extract stats for each season
player_stats = []
for season_stats in data['stats']:
    season_data = season_stats['stats']
    season_data['season'] = season_stats['season']
    player_stats.append(season_data)

# Create DataFrame from the list of dictionaries
ohtani_df = pd.DataFrame(player_stats)

# Display DataFrame
ohtani_df
# Out:
#    gamesPlayed  groundOuts  airOuts  runs  doubles  triples  homeRuns  \
# 0          114          71       61    59       21        2        22
# 1          106         101       67    51       20        5        18
# 2           46          44       30    23        6        0         7
# 3          158         101      111   103       26        8        46
# 4          157         136      132    90       30        6        34
# 5          135         103      103   102       26        8        44
#
#    strikeOuts  baseOnBalls  intentionalWalks  ...  totalBases  rbi leftOnBase  \
# 0         102           37                 2  ...         184   61        128
# 1         110           33                 1  ...         194   62        192
# 2          50           22                 0  ...          56   24         99
# 3         189           96                20  ...         318  100        187
# 4         161           72                14  ...         304   95        196
# ...

# %%
ohtani_df.columns
# Out:
# Index(['gamesPlayed', 'groundOuts', 'airOuts', 'runs', 'doubles', 'triples',
#        'homeRuns', 'strikeOuts', 'baseOnBalls', 'intentionalWalks', 'hits',
#        'hitByPitch', 'avg', 'atBats', 'obp', 'slg', 'ops', 'caughtStealing',
#        'stolenBases', 'stolenBasePercentage', 'groundIntoDoublePlay',
#        'numberOfPitches', 'plateAppearances', 'totalBases', 'rbi',
#        'leftOnBase', 'sacBunts', 'sacFlies', 'babip', 'groundOutsToAirouts',
#        'catchersInterference', 'atBatsPerHomeRun', 'season'],
#       dtype='object')

# %%
# Column to move to the front
column_to_move = 'season'

# Extract the column
column = ohtani_df[column_to_move]

# Drop the column from its original position
ohtani_df.drop(columns=[column_to_move], inplace=True)

# Insert the column at the front
ohtani_df.insert(0, column_to_move, column)

ohtani_df.insert(0, 'name', 'Shohei Ohtani')

# Display the DataFrame
ohtani_df
# Out:
#             name season  gamesPlayed  groundOuts  airOuts  runs  doubles  \
# 0  Shohei Ohtani   2018          114          71       61    59       21
# 1  Shohei Ohtani   2019          106         101       67    51       20
# 2  Shohei Ohtani   2020           46          44       30    23        6
# 3  Shohei Ohtani   2021          158         101      111   103       26
# 4  Shohei Ohtani   2022          157         136      132    90       30
# 5  Shohei Ohtani   2023          135         103      103   102       26
#
#    triples  homeRuns  strikeOuts  ...  plateAppearances  totalBases  rbi  \
# 0        2        22         102  ...               367         184   61
# 1        5        18         110  ...               425         194   62
# 2        0         7          50  ...               175          56   24
# 3        8        46         189  ...               639         318  100
# 4        6        34         161  ...               666         304   95
# ...

# %%
ohtani_df = ohtani_df[['name', 'season', 'gamesPlayed', 'avg', 'ops', 'homeRuns', 'runs', 'totalBases', 'rbi', 'babip']]
ohtani_df_comp = ohtani_df[ohtani_df['season'] == '2023']
ohtani_df_comp
# Out:
#             name season  gamesPlayed   avg    ops  homeRuns  runs  totalBases  \
# 5  Shohei Ohtani   2023          135  .304  1.066        44   102         325
#
#    rbi babip
# 5   95  .342

# %%
ohtani_2019 = ohtani_df[ohtani_df['season'] == '2019']
ohtani_2019
# Out:
#             name season  gamesPlayed   avg   ops  homeRuns  runs  totalBases  \
# 1  Shohei Ohtani   2019          106  .286  .848        18    51         194
#
#    rbi babip
# 1   62  .354

# %%
# Given dictionary
data = statsapi.player_stat_data(statsapi.lookup_player('judge, aaron')[0]['id'], group="hitting", type="yearByYear", sportId=1)

# Flatten the dictionary and extract stats for each season
player_stats = []
for season_stats in data['stats']:
    season_data = season_stats['stats']
    season_data['season'] = season_stats['season']
    player_stats.append(season_data)

# Create DataFrame from the list of dictionaries
judge_df = pd.DataFrame(player_stats)

# Display DataFrame
judge_df
# Out:
#    gamesPlayed  groundOuts  airOuts  runs  doubles  triples  homeRuns  \
# 0           27          11       17    10        2        0         4
# 1          155          85       99   128       24        3        52
# 2          112          77       74    77       22        0        27
# 3          102          71       64    75       18        1        27
# 4           28          22       21    23        3        0         9
# 5          148         127      112    89       24        0        39
# 6          157         111      112   133       28        0        62
# 7          106          54       88    79       16        0        37
#
#    strikeOuts  baseOnBalls  intentionalWalks  ...  totalBases  rbi leftOnBase  \
# 0          42            9                 0  ...          29   10         41
# 1         208          127                11  ...         340  114        248
# 2         152           76                 3  ...         218   67        143
# ...

# %%
# Column to move to the front
column_to_move = 'season'

# Extract the column
column = judge_df[column_to_move]

# Drop the column from its original position
judge_df.drop(columns=[column_to_move], inplace=True)

# Insert the column at the front
judge_df.insert(0, column_to_move, column)

judge_df.insert(0, 'name', 'Aaron Judge')

# Display the DataFrame
judge_df
# Out:
#           name season  gamesPlayed  groundOuts  airOuts  runs  doubles  \
# 0  Aaron Judge   2016           27          11       17    10        2
# 1  Aaron Judge   2017          155          85       99   128       24
# 2  Aaron Judge   2018          112          77       74    77       22
# 3  Aaron Judge   2019          102          71       64    75       18
# 4  Aaron Judge   2020           28          22       21    23        3
# 5  Aaron Judge   2021          148         127      112    89       24
# 6  Aaron Judge   2022          157         111      112   133       28
# 7  Aaron Judge   2023          106          54       88    79       16
#
#    triples  homeRuns  strikeOuts  ...  plateAppearances  totalBases  rbi  \
# 0        0         4          42  ...                95          29   10
# 1        3        52         208  ...               678         340  114
# 2        0        27         152  ...               498         218   67
# ...

# %%
judge_df = judge_df[['name', 'season', 'gamesPlayed', 'avg', 'ops', 'homeRuns', 'runs', 'totalBases', 'rbi', 'babip']]
judge_df_comp = judge_df[judge_df['season'] == '2022']
judge_df_comp
# Out:
#           name season  gamesPlayed   avg    ops  homeRuns  runs  totalBases  \
# 6  Aaron Judge   2022          157  .311  1.111        62   133         391
#
#    rbi babip
# 6  131  .340

# %%
ohtani_df_comp = ohtani_df_comp.append(judge_df[judge_df['season'] == '2022'])
ohtani_df_comp
# Out:
# C:\Users\jgold\AppData\Local\Temp\ipykernel_8552\2690580331.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ohtani_df_comp = ohtani_df_comp.append(judge_df[judge_df['season'] == '2022'])
#             name season  gamesPlayed   avg    ops  homeRuns  runs  totalBases  \
# 5  Shohei Ohtani   2023          135  .304  1.066        44   102         325
# 6    Aaron Judge   2022          157  .311  1.111        62   133         391
#
#    rbi babip
# 5   95  .342
# 6  131  .340

# %%
# Given dictionary
data = statsapi.player_stat_data(statsapi.lookup_player('trout, mike')[0]['id'], group="hitting", type="yearByYear", sportId=1)

# Flatten the dictionary and extract stats for each season
player_stats = []
for season_stats in data['stats']:
    season_data = season_stats['stats']
    season_data['season'] = season_stats['season']
    player_stats.append(season_data)

# Create DataFrame from the list of dictionaries
trout_df = pd.DataFrame(player_stats)

# Display DataFrame
trout_df
# Out:
#     gamesPlayed  groundOuts  airOuts  runs  doubles  triples  homeRuns  \
# 0            40          27       40    20        6        0         5
# 1           139         133      112   129       27        8        30
# 2           157         123      148   109       39        9        27
# 3           157          94      161   115       39        9        36
# 4           159         112      138   104       32        6        41
# 5           159         121      123   123       32        5        29
# 6           114          81      112    92       25        3        33
# 7           140          75      129   101       24        4        39
# 8           134          70      147   110       27        2        45
# 9            53          28       63    41        9        2        17
# 10           36          20       17    23        8        1         8
# 11          119          53      123    85       28        2        40
# ...

# %%
# Column to move to the front
column_to_move = 'season'

# Extract the column
column = trout_df[column_to_move]

# Drop the column from its original position
trout_df.drop(columns=[column_to_move], inplace=True)

# Insert the column at the front
trout_df.insert(0, column_to_move, column)

trout_df.insert(0, 'name', 'Mike Trout')

# Display the DataFrame
trout_df
# Out:
#           name season  gamesPlayed  groundOuts  airOuts  runs  doubles  \
# 0   Mike Trout   2011           40          27       40    20        6
# 1   Mike Trout   2012          139         133      112   129       27
# 2   Mike Trout   2013          157         123      148   109       39
# 3   Mike Trout   2014          157          94      161   115       39
# 4   Mike Trout   2015          159         112      138   104       32
# 5   Mike Trout   2016          159         121      123   123       32
# 6   Mike Trout   2017          114          81      112    92       25
# 7   Mike Trout   2018          140          75      129   101       24
# 8   Mike Trout   2019          134          70      147   110       27
# 9   Mike Trout   2020           53          28       63    41        9
# 10  Mike Trout   2021           36          20       17    23        8
# 11  Mike Trout   2022          119          53      123    85       28
# ...

# %%
trout_df = trout_df[['name', 'season', 'gamesPlayed', 'avg', 'ops', 'homeRuns', 'runs', 'totalBases', 'rbi', 'babip']]
trout_df_comp = trout_df[trout_df['season'] == '2019']
trout_df_comp
# Out:
#          name season  gamesPlayed   avg    ops  homeRuns  runs  totalBases  \
# 8  Mike Trout   2019          134  .291  1.083        45   110         303
#
#    rbi babip
# 8  104  .298

# %%
ohtani_df_comp = pd.concat([ohtani_df_comp, trout_df_comp], ignore_index=True)
ohtani_df_comp
# Out:
#             name season  gamesPlayed   avg    ops  homeRuns  runs  totalBases  \
# 0  Shohei Ohtani   2023          135  .304  1.066        44   102         325
# 1    Aaron Judge   2022          157  .311  1.111        62   133         391
# 2     Mike Trout   2019          134  .291  1.083        45   110         303
#
#    rbi babip
# 0   95  .342
# 1  131  .340
# 2  104  .298

# %%
# Given dictionary
data = statsapi.player_stat_data(statsapi.lookup_player('betts, mookie')[0]['id'], group="hitting", type="yearByYear", sportId=1)

# Flatten the dictionary and extract stats for each season
player_stats = []
for season_stats in data['stats']:
    season_data = season_stats['stats']
    season_data['season'] = season_stats['season']
    player_stats.append(season_data)

# Create DataFrame from the list of dictionaries
betts_df = pd.DataFrame(player_stats)

# Display DataFrame
betts_df
# Out:
#    gamesPlayed  groundOuts  airOuts  runs  doubles  triples  homeRuns  \
# 0           52          44       60    34       12        1         5
# 1          145         138      212    92       42        8        18
# 2          158         169      216   122       42        5        31
# 3          153         165      223   101       46        2        24
# 4          136          93      161   129       47        5        32
# 5          150         121      208   135       40        5        29
# 6           55          38       80    47        9        1        16
# 7          122         105      157    93       29        3        23
# 8          142         127      191   117       40        3        35
# 9          152          97      206   126       40        1        39
#
#    strikeOuts  baseOnBalls  intentionalWalks  ...  totalBases  rbi leftOnBase  \
# 0          31           21                 0  ...          84   18         68
# ...

# %%
# Column to move to the front
column_to_move = 'season'

# Extract the column
column = betts_df[column_to_move]

# Drop the column from its original position
betts_df.drop(columns=[column_to_move], inplace=True)

# Insert the column at the front
betts_df.insert(0, column_to_move, column)

betts_df.insert(0, 'name', 'Mookie Betts')

# Display the DataFrame
betts_df
# Out:
#            name season  gamesPlayed  groundOuts  airOuts  runs  doubles  \
# 0  Mookie Betts   2014           52          44       60    34       12
# 1  Mookie Betts   2015          145         138      212    92       42
# 2  Mookie Betts   2016          158         169      216   122       42
# 3  Mookie Betts   2017          153         165      223   101       46
# 4  Mookie Betts   2018          136          93      161   129       47
# 5  Mookie Betts   2019          150         121      208   135       40
# 6  Mookie Betts   2020           55          38       80    47        9
# 7  Mookie Betts   2021          122         105      157    93       29
# 8  Mookie Betts   2022          142         127      191   117       40
# 9  Mookie Betts   2023          152          97      206   126       40
#
#    triples  homeRuns  strikeOuts  ...  plateAppearances  totalBases  rbi  \
# 0        1         5          31  ...               213          84   18
# ...

# %%
betts_df = betts_df[['name', 'season', 'gamesPlayed', 'avg', 'ops', 'homeRuns', 'runs', 'totalBases', 'rbi', 'babip']]
betts_df_comp = betts_df[betts_df['season'] == '2018']
betts_df_comp
# Out:
#            name season  gamesPlayed   avg    ops  homeRuns  runs  totalBases  \
# 4  Mookie Betts   2018          136  .346  1.078        32   129         333
#
#    rbi babip
# 4   80  .368

# %%
ohtani_df_comp = pd.concat([ohtani_df_comp, betts_df_comp], ignore_index=True)
ohtani_df_comp
# Out:
#             name season  gamesPlayed   avg    ops  homeRuns  runs  totalBases  \
# 0  Shohei Ohtani   2023          135  .304  1.066        44   102         325
# 1    Aaron Judge   2022          157  .311  1.111        62   133         391
# 2     Mike Trout   2019          134  .291  1.083        45   110         303
# 3   Mookie Betts   2018          136  .346  1.078        32   129         333
#
#    rbi babip
# 0   95  .342
# 1  131  .340
# 2  104  .298
# 3   80  .368

# %%
# Given dictionary
data = statsapi.player_stat_data(statsapi.lookup_player('Acuña Jr., Ronald')[0]['id'], group="hitting", type="yearByYear", sportId=1)

# Flatten the dictionary and extract stats for each season
player_stats = []
for season_stats in data['stats']:
    season_data = season_stats['stats']
    season_data['season'] = season_stats['season']
    player_stats.append(season_data)

# Create DataFrame from the list of dictionaries
acuna_df = pd.DataFrame(player_stats)

# Display DataFrame
acuna_df
# Out:
#    gamesPlayed  groundOuts  airOuts  runs  doubles  triples  homeRuns  \
# 0          111          90       96    78       26        4        26
# 1          156         120      144   127       22        2        41
# 2           46          29       31    46       11        0        14
# 3           82          51       82    72       19        1        24
# 4          119         120      100    71       24        0        15
# 5          159         193      152   149       35        4        41
#
#    strikeOuts  baseOnBalls  intentionalWalks  ...  totalBases  rbi leftOnBase  \
# 0         123           45                 2  ...         239   64        129
# 1         188           76                 4  ...         324  101        196
# 2          60           38                 2  ...          93   29         56
# 3          85           49                 2  ...         177   52        100
# 4         126           53                 4  ...         193   50        147
# ...

# %%
# Column to move to the front
column_to_move = 'season'

# Extract the column
column = acuna_df[column_to_move]

# Drop the column from its original position
acuna_df.drop(columns=[column_to_move], inplace=True)

# Insert the column at the front
acuna_df.insert(0, column_to_move, column)

acuna_df.insert(0, 'name', 'Ronald Acuna Jr.')

# Display the DataFrame
acuna_df
# Out:
#                name season  gamesPlayed  groundOuts  airOuts  runs  doubles  \
# 0  Ronald Acuna Jr.   2018          111          90       96    78       26
# 1  Ronald Acuna Jr.   2019          156         120      144   127       22
# 2  Ronald Acuna Jr.   2020           46          29       31    46       11
# 3  Ronald Acuna Jr.   2021           82          51       82    72       19
# 4  Ronald Acuna Jr.   2022          119         120      100    71       24
# 5  Ronald Acuna Jr.   2023          159         193      152   149       35
#
#    triples  homeRuns  strikeOuts  ...  plateAppearances  totalBases  rbi  \
# 0        4        26         123  ...               487         239   64
# 1        2        41         188  ...               715         324  101
# 2        0        14          60  ...               202          93   29
# 3        1        24          85  ...               360         177   52
# ...

# %%
acuna_df = acuna_df[['name', 'season', 'gamesPlayed', 'avg', 'ops', 'homeRuns', 'runs', 'totalBases', 'rbi', 'babip']]
acuna_df_comp = acuna_df[acuna_df['season'] == '2023']
acuna_df_comp
# Out:
#                name season  gamesPlayed   avg    ops  homeRuns  runs  \
# 5  Ronald Acuna Jr.   2023          159  .337  1.012        41   149
#
#    totalBases  rbi babip
# 5         383  106  .338

# %%
ohtani_df_comp = pd.concat([ohtani_df_comp, acuna_df_comp], ignore_index=True)
ohtani_df_comp
# Out:
#                name season  gamesPlayed   avg    ops  homeRuns  runs  \
# 0     Shohei Ohtani   2023          135  .304  1.066        44   102
# 1       Aaron Judge   2022          157  .311  1.111        62   133
# 2        Mike Trout   2019          134  .291  1.083        45   110
# 3      Mookie Betts   2018          136  .346  1.078        32   129
# 4  Ronald Acuna Jr.   2023          159  .337  1.012        41   149
#
#    totalBases  rbi babip
# 0         325   95  .342
# 1         391  131  .340
# 2         303  104  .298
# 3         333   80  .368
# 4         383  106  .338

# %%
# Row index to move to the top
row_index_to_move = 4

# Extract the row to move
row_to_move = ohtani_df_comp.iloc[row_index_to_move]

# Drop the row from its original position
ohtani_df_comp = ohtani_df_comp.drop(row_index_to_move)

# Reinsert the row at the beginning of the DataFrame
ohtani_df_comp = pd.concat([row_to_move.to_frame().T, ohtani_df_comp], ignore_index=True)
ohtani_df_comp
# Out:
#                name season gamesPlayed   avg    ops homeRuns runs totalBases  \
# 0  Ronald Acuna Jr.   2023         159  .337  1.012       41  149        383
# 1     Shohei Ohtani   2023         135  .304  1.066       44  102        325
# 2       Aaron Judge   2022         157  .311  1.111       62  133        391
# 3        Mike Trout   2019         134  .291  1.083       45  110        303
# 4      Mookie Betts   2018         136  .346  1.078       32  129        333
#
#    rbi babip
# 0  106  .338
# 1   95  .342
# 2  131  .340
# 3  104  .298
# 4   80  .368

# %%
row_to_insert = ohtani_df[ohtani_df['season'] == '2021']
print(row_to_insert)
# Out:
#             name season  gamesPlayed   avg   ops  homeRuns  runs  totalBases  \
# 3  Shohei Ohtani   2021          158  .257  .964        46   103         318
#
#    rbi babip
# 3  100  .303

# %%
# Index at which to insert
index_to_insert = 3
row_to_insert = ohtani_df[ohtani_df['season'] == '2021']

# Split the main DataFrame into two parts
df_part1 = ohtani_df_comp.iloc[:index_to_insert]
df_part2 = ohtani_df_comp.iloc[index_to_insert:]

# Concatenate the parts along with the DataFrame to insert
ohtani_df_comp = pd.concat([df_part1, row_to_insert, df_part2], ignore_index=True)

ohtani_df_comp
# Out:
#                name season gamesPlayed   avg    ops homeRuns runs totalBases  \
# 0  Ronald Acuna Jr.   2023         159  .337  1.012       41  149        383
# 1     Shohei Ohtani   2023         135  .304  1.066       44  102        325
# 2       Aaron Judge   2022         157  .311  1.111       62  133        391
# 3     Shohei Ohtani   2021         158  .257   .964       46  103        318
# 4        Mike Trout   2019         134  .291  1.083       45  110        303
# 5      Mookie Betts   2018         136  .346  1.078       32  129        333
#
#    rbi babip
# 0  106  .338
# 1   95  .342
# 2  131  .340
# 3  100  .303
# 4  104  .298
# 5   80  .368

# %%
#Examine Ohtani pitching stats next
# Given dictionary
data = statsapi.player_stat_data(statsapi.lookup_player('ohtani, shohei')[0]['id'], group="pitching", type="yearByYear", sportId=1)

# Flatten the dictionary and extract stats for each season
player_stats = []
for season_stats in data['stats']:
    season_data = season_stats['stats']
    season_data['season'] = season_stats['season']
    player_stats.append(season_data)

# Create DataFrame from the list of dictionaries
ohtani_pitch = pd.DataFrame(player_stats)

# Display DataFrame
ohtani_pitch
# Out:
#    gamesPlayed  gamesStarted  groundOuts  airOuts  runs  doubles  triples  \
# 0           10            10          37       50    19        6        0
# 1            2             2           0        2     7        0        0
# 2           23            23         113      112    48       23        0
# 3           28            28         129      141    45       23        2
# 4           23            23         114       98    50       15        0
#
#    homeRuns  strikeOuts  baseOnBalls  ...  walksPer9Inn  hitsPer9Inn  \
# 0         6          63           22  ...          3.83         6.62
# 1         0           3            8  ...         43.20        16.20
# 2        15         156           44  ...          3.04         6.77
# 3        14         219           44  ...          2.39         6.72
# 4        18         167           55  ...          3.75         5.80
#
#    runsScoredPer9 homeRunsPer9  inheritedRunners inheritedRunnersScored  \
# ...

# %%
columns_to_keep = ['season', 'gamesStarted', 'wins', 'losses', 'inningsPitched', 'era', 'earnedRuns', 'avg', 'ops', 'whip', 'strikeOuts', 'strikeoutWalkRatio', 'totalBases', 'walksPer9Inn', 'hitsPer9Inn', 'runsScoredPer9']

# %%
ohtani_pitch_comp = ohtani_pitch.loc[:, columns_to_keep]
ohtani_pitch_comp
# Out:
#   season  gamesStarted  wins  losses inningsPitched    era  earnedRuns   avg  \
# 0   2018            10     4       2           51.2   3.31          19  .203
# 1   2020             2     0       1            1.2  37.80           7  .375
# 2   2021            23     9       2          130.1   3.18          46  .207
# 3   2022            28    15       9          166.0   2.33          43  .203
# 4   2023            23    10       5          132.0   3.14          46  .184
#
#      ops  whip  strikeOuts strikeoutWalkRatio  totalBases walksPer9Inn  \
# 0   .621  1.16          63               2.86          62         3.83
# 1  1.063  6.60           3               0.38           3        43.20
# 2   .637  1.09         156               3.55         166         3.04
# 3   .574  1.01         219               4.98         193         2.39
# 4   .618  1.06         167               3.04         154         3.75
#
#   hitsPer9Inn runsScoredPer9
# 0        6.62           3.31
# ...

# %%
print(statsapi.league_leaders('earnedRunAverage', season=2023, limit=20, statGroup='pitching', leagueId=None, gameTypes='R', playerPool=None, sportId=1, statType=None))
# Out:
# Rank Name                 Team                    Value
#  1   Blake Snell          San Diego Padres        2.25
#  2   Gerrit Cole          New York Yankees        2.63
#  3   Sonny Gray           Minnesota Twins         2.79
#  4   Kyle Bradish         Baltimore Orioles       2.83
#  5   Kodai Senga          New York Mets           2.98
#  6   Justin Steele        Chicago Cubs            3.06
#  7   Kevin Gausman        Toronto Blue Jays       3.16
#  8   Jordan Montgomery    Texas Rangers           3.20
#  9   Justin Verlander     Houston Astros          3.22
#  10  Logan Webb           San Francisco Giants    3.25
#  11  Merrill Kelly        Arizona Diamondbacks    3.29
#  12  Luis Castillo        Seattle Mariners        3.34
#  13  George Kirby         Seattle Mariners        3.35
#  14  Corbin Burnes        Milwaukee Brewers       3.39
#  15  Framber Valdez       Houston Astros          3.45
#  16  Zac Gallen           Arizona Diamondbacks    3.47
# ...

# %%
#Examine Ohtani pitching stats next

pitch_dict = {'Ohtani': statsapi.lookup_player('ohtani, shohei')[0]['id'], 'Cole':statsapi.lookup_player('cole, gerrit')[0]['id']}

data = []
for player_name, player_id in pitch_dict.items():  # Iterate over player names and IDs
    player_data = statsapi.player_stat_data(player_id, group="pitching", type="career", sportId=1)
    player_data['player_name'] = player_name  # Add player name to the data dictionary
    data.append(player_data)

# Flatten the dictionary and extract stats for each season
player_stats = []
for d in data:
    for season_stats in d['stats']:
        season_data = season_stats['stats']
        season_data['season'] = season_stats['season']
        season_data['player_name'] = d['player_name']  # Add player name to each season's data
        player_stats.append(season_data)

# Create DataFrame from the list of dictionaries
ohtani_pitch = pd.DataFrame(player_stats)

# Display DataFrame
ohtani_pitch
# Out:
#    gamesPlayed  gamesStarted  groundOuts  airOuts  runs  doubles  triples  \
# 0           86            86         393      403   169       67        2
# 1          300           300        1646     1596   702      302       24
#
#    homeRuns  strikeOuts  baseOnBalls  ...  hitsPer9Inn  runsScoredPer9  \
# 0        53         608          173  ...         6.50            3.16
# 1       206        2152          471  ...         7.50            3.40
#
#    homeRunsPer9 inheritedRunners  inheritedRunnersScored catchersInterference  \
# 0          0.99                0                       0                    2
# 1          1.00                0                       0                    2
#
#   sacBunts sacFlies  season  player_name
# 0        2        9    None       Ohtani
# 1       36       31    None         Cole
#
# [2 rows x 62 columns]

# %%
column_name = 'player_name'

# Pop the column from its current position
column = ohtani_pitch.pop(column_name)

# Insert the column at the beginning of the DataFrame
ohtani_pitch.insert(0, column_name, column)

columns_to_keep = ['player_name', 'gamesStarted', 'era', 'avg', 'ops', 'whip', 'strikeoutWalkRatio', 'walksPer9Inn', 'hitsPer9Inn', 'runsScoredPer9']

ohtani_pitch = ohtani_pitch.loc[:, columns_to_keep]
ohtani_pitch
# Out:
#   player_name  gamesStarted   era   avg   ops  whip strikeoutWalkRatio  \
# 0      Ohtani            86  3.01  .200  .612  1.08               3.51
# 1        Cole           300  3.17  .225  .645  1.09               4.57
#
#   walksPer9Inn hitsPer9Inn runsScoredPer9
# 0         3.23        6.50           3.16
# 1         2.28        7.50           3.40

# %%
ohtani_pitch
# Out:
#   player_name  gamesStarted   era   avg   ops  whip strikeoutWalkRatio  \
# 0      Ohtani            86  3.01  .200  .612  1.08               3.51
# 1        Cole           300  3.17  .225  .645  1.09               4.57
#
#   walksPer9Inn hitsPer9Inn runsScoredPer9
# 0         3.23        6.50           3.16
# 1         2.28        7.50           3.40

# %%
#compare 2023 seasons between Ohtani and Cole

# %%
pitch_dict = statsapi.lookup_player('ruth,', season = 1930)
print(pitch_dict)
# Out:
# [{'id': 121578, 'fullName': 'Babe Ruth', 'firstName': 'George', 'lastName': 'Ruth', 'currentTeam': {'id': 147}, 'primaryPosition': {'code': '9', 'abbreviation': 'RF'}, 'useName': 'Babe', 'boxscoreName': 'Ruth', 'nickName': 'The Bambino', 'mlbDebutDate': '1914-07-11', 'nameFirstLast': 'Babe Ruth', 'firstLastName': 'Babe Ruth', 'lastFirstName': 'Ruth, Babe', 'lastInitName': 'Ruth, B', 'initLastName': 'B Ruth', 'fullFMLName': 'George Herman Ruth', 'fullLFMName': 'Ruth, George Herman'}]

# %%
statsapi.roster(147, rosterType=None, date='05/01/1930')
# Out:
# '#    C   Arndt Jorgens\n#    OF  Babe Ruth\n#    OF  Ben Chapman\n#    C   Benny Bengough\n#    C   Bill Dickey\n#    P   Bill Henderson\n#    OF  Bill Karlon\n#    SS  Billy Werber\n#    C   Bubbles Hargrave\n#    OF  Cedric Durst\n#    OF  Dusty Cooke\n#    OF  Earle Combs\n#    P   Ed Wells\n#    P   Foster Edwards\n#    P   Frank Barnes\n#    P   George Pipgras\n#    P   Gordon Rhodes\n#    P   Hank Johnson\n#    OF  Harry Rice\n#    P   Herb Pennock\n#    2B  Jimmie Reese\n#    P   Ken Holloway\n#    P   Lefty Gomez\n#    1B  Lou Gehrig\n#    P   Lou McEvoy\n#    SS  Lyn Lary\n#    SS  Mark Koenig\n#    P   Red Ruffing\n#    P   Roy Sherid\n#    P   Sam Gibson\n#    OF  Sammy Byrd\n#    P   Tom Zachary\n#    2B  Tony Lazzeri\n#    P   Waite Hoyt\n#    SS  Yats Wuestling\n'

# %%
ruth_data = statsapi.player_stat_data(121578, group='pitching', type="yearByYear", sportId=1)

# Flatten the dictionary and extract stats for each season
ruth_stats = []
for season_data in ruth_data['stats']:
    season_stats = season_data['stats']
    season_stats['season'] = season_data['season']
    ruth_stats.append(season_stats)

# Create DataFrame from the list of dictionaries
ruth_df = pd.DataFrame(ruth_stats)

# Display DataFrame
ruth_df
# Out:
#    gamesPlayed  gamesStarted  runs  homeRuns  strikeOuts  baseOnBalls  hits  \
# 0            4             3    12         1           3            7    21
# 1           32            28    80         3         112           85   166
# 2           44            41    83         0         170          118   230
# 3           41            38    93         2         128          108   244
# 4           20            19    51         1          40           49   125
# 5           17            15    59         2          30           58   148
# 6            1             1     4         0           0            2     3
# 7            2             1    10         1           2            9    14
# 8            1             1     3         0           3            2    11
# 9            1             1     5         0           0            3    12
#
#    hitByPitch   avg  atBats  ... winPercentage gamesFinished  \
# 0           0  .236      89  ...          .667             0
# ...

# %%
column_name = 'season'

# Pop the column from its current position
column = ruth_df.pop(column_name)

# Insert the column at the beginning of the DataFrame
ruth_df.insert(0, column_name, column)

columns_to_keep = ['gamesStarted', 'season', 'era', 'avg', 'whip', 'strikeoutWalkRatio', 'walksPer9Inn', 'hitsPer9Inn', 'runsScoredPer9']

ruth_pitch = ruth_df.loc[:, columns_to_keep]
ruth_pitch
# Out:
#    gamesStarted season   era   avg  whip strikeoutWalkRatio walksPer9Inn  \
# 0             3   1914  3.91  .236  1.22               0.43         2.74
# 1            28   1915  2.44  .212  1.15               1.32         3.51
# 2            41   1916  1.75  .201  1.08               1.44         3.28
# 3            38   1917  2.01  .211  1.08               1.19         2.98
# 4            19   1918  2.22  .205  1.05               0.82         2.65
# 5            15   1919  2.97  .290  1.55               0.52         3.92
# 6             1   1920  4.50  .200  1.25               0.00         4.50
# 7             1   1921  9.00  .350  2.56               0.22         9.00
# 8             1   1930  3.00  .306  1.44               1.50         2.00
# 9             1   1933  5.00  .308  1.67               0.00         3.00
#
#   hitsPer9Inn runsScoredPer9
# 0        8.22           4.70
# 1        6.86           3.31
# 2        6.40           2.31
# 3        6.73           2.56
# ...

# %%
ruth_data
# Out:
# {'id': 121578,
#  'first_name': 'Babe',
#  'last_name': 'Ruth',
#  'active': False,
#  'current_team': 'Boston Braves',
#  'position': 'RF',
#  'nickname': 'The Bambino',
#  'last_played': '1935-05-30',
#  'mlb_debut': '1914-07-11',
#  'bat_side': 'Left',
#  'pitch_hand': 'Left',
#  'stats': [{'type': 'yearByYear',
#    'group': 'pitching',
#    'season': '1914',
#    'stats': {'gamesPlayed': 4,
#     'gamesStarted': 3,
#     'runs': 12,
#     'homeRuns': 1,
#     'strikeOuts': 3,
#     'baseOnBalls': 7,
#     'hits': 21,
#     'hitByPitch': 0,
#     'avg': '.236',
#     'atBats': 89,
#     'obp': '.292',
#     'era': '3.91',
#     'inningsPitched': '23.0',
#     'wins': 2,
#     'losses': 1,
#     'saves': 0,
#     'earnedRuns': 10,
#     'whip': '1.22',
#     'battersFaced': 96,
#     'outs': 69,
#     'gamesPitched': 4,
#     'completeGames': 1,
#     'shutouts': 0,
#     'hitBatsmen': 0,
#     'balks': 0,
#     'wildPitches': 0,
#     'winPercentage': '.667',
# ...

# %%
# Given dictionary
data = statsapi.player_stat_data(statsapi.lookup_player('freeman, freddie')[0]['id'], group="hitting", type="yearByYear", sportId=1)

# Flatten the dictionary and extract stats for each season
player_stats = []
for season_stats in data['stats']:
    season_data = season_stats['stats']
    season_data['season'] = season_stats['season']
    player_stats.append(season_data)

# Create DataFrame from the list of dictionaries
freeman_df = pd.DataFrame(player_stats)

# Display DataFrame
freeman_df
# Out:
#     gamesPlayed  groundOuts  airOuts  runs  doubles  triples  homeRuns  \
# 0            20           7        5     3        1        0         1
# 1           157         142      131    67       32        0        21
# 2           147         122      158    91       33        2        23
# 3           147         129      130    89       27        2        23
# 4           162         140      150    93       43        4        18
# 5           118          94      111    62       27        0        18
# 6           158         102      143   102       43        6        34
# 7           117          93      119    84       35        2        28
# 8           162         147      154    94       44        4        23
# 9           158         143      153   113       34        2        38
# 10           60          45       59    51       23        1        13
# 11          159         163      152   120       25        2        31
# ...

# %%
# Column to move to the front
column_to_move = 'season'

# Extract the column
column = freeman_df[column_to_move]

# Drop the column from its original position
freeman_df.drop(columns=[column_to_move], inplace=True)

# Insert the column at the front
freeman_df.insert(0, column_to_move, column)

freeman_df.insert(0, 'name', 'Freddie Freeman')

# Display the DataFrame
freeman_df
# Out:
#                name season  gamesPlayed  groundOuts  airOuts  runs  doubles  \
# 0   Freddie Freeman   2010           20           7        5     3        1
# 1   Freddie Freeman   2011          157         142      131    67       32
# 2   Freddie Freeman   2012          147         122      158    91       33
# 3   Freddie Freeman   2013          147         129      130    89       27
# 4   Freddie Freeman   2014          162         140      150    93       43
# 5   Freddie Freeman   2015          118          94      111    62       27
# 6   Freddie Freeman   2016          158         102      143   102       43
# 7   Freddie Freeman   2017          117          93      119    84       35
# 8   Freddie Freeman   2018          162         147      154    94       44
# 9   Freddie Freeman   2019          158         143      153   113       34
# 10  Freddie Freeman   2020           60          45       59    51       23
# ...

# %%
freeman_df = freeman_df[['name', 'season', 'gamesPlayed', 'avg', 'ops', 'homeRuns', 'runs', 'totalBases', 'rbi', 'babip']]
freeman_df
# Out:
#                name season  gamesPlayed   avg    ops  homeRuns  runs  \
# 0   Freddie Freeman   2010           20  .167   .500         1     3
# 1   Freddie Freeman   2011          157  .282   .794        21    67
# 2   Freddie Freeman   2012          147  .259   .796        23    91
# 3   Freddie Freeman   2013          147  .319   .897        23    89
# 4   Freddie Freeman   2014          162  .288   .847        18    93
# 5   Freddie Freeman   2015          118  .276   .841        18    62
# 6   Freddie Freeman   2016          158  .302   .969        34   102
# 7   Freddie Freeman   2017          117  .307   .989        28    84
# 8   Freddie Freeman   2018          162  .309   .893        23    94
# 9   Freddie Freeman   2019          158  .295   .938        38   113
# 10  Freddie Freeman   2020           60  .341  1.102        13    51
# 11  Freddie Freeman   2021          159  .300   .896        31   120
# 12  Freddie Freeman   2022          159  .325   .918        21   117
# ...

# %%
# Index at which to insert
index_to_insert = 4
row_to_insert = freeman_df[freeman_df['season'] == '2020']

# Split the main DataFrame into two parts
df_part1 = ohtani_df_comp.iloc[:index_to_insert]
df_part2 = ohtani_df_comp.iloc[index_to_insert:]

# Concatenate the parts along with the DataFrame to insert
ohtani_df_comp = pd.concat([df_part1, row_to_insert, df_part2], ignore_index=True)

ohtani_df_comp
# Out:
#                name season gamesPlayed   avg    ops homeRuns runs totalBases  \
# 0  Ronald Acuna Jr.   2023         159  .337  1.012       41  149        383
# 1     Shohei Ohtani   2023         135  .304  1.066       44  102        325
# 2       Aaron Judge   2022         157  .311  1.111       62  133        391
# 3     Shohei Ohtani   2021         158  .257   .964       46  103        318
# 4   Freddie Freeman   2020          60  .341  1.102       13   51        137
# 5   Freddie Freeman   2020          60  .341  1.102       13   51        137
# 6        Mike Trout   2019         134  .291  1.083       45  110        303
# 7      Mookie Betts   2018         136  .346  1.078       32  129        333
#
#    rbi babip  ...  stolenBasePercentage  groundIntoDoublePlay  \
# 0  106  .338  ...                   NaN                   NaN
# 1   95  .342  ...                   NaN                   NaN
# 2  131  .340  ...                   NaN                   NaN
# ...

# %%
# Drop a row by index
index_to_drop = 4  # Index of the row to drop
ohtani_df_comp = ohtani_df_comp.drop(index_to_drop)
ohtani_df_comp
# Out:
#                name season gamesPlayed   avg    ops homeRuns runs totalBases  \
# 0  Ronald Acuna Jr.   2023         159  .337  1.012       41  149        383
# 1     Shohei Ohtani   2023         135  .304  1.066       44  102        325
# 2       Aaron Judge   2022         157  .311  1.111       62  133        391
# 3     Shohei Ohtani   2021         158  .257   .964       46  103        318
# 5   Freddie Freeman   2020          60  .341  1.102       13   51        137
# 6        Mike Trout   2019         134  .291  1.083       45  110        303
# 7      Mookie Betts   2018         136  .346  1.078       32  129        333
#
#    rbi babip  ...  stolenBasePercentage  groundIntoDoublePlay  \
# 0  106  .338  ...                   NaN                   NaN
# 1   95  .342  ...                   NaN                   NaN
# 2  131  .340  ...                   NaN                   NaN
# 3  100  .303  ...                   NaN                   NaN
# ...

# %%
ohtani_df_comp = ohtani_df_comp[['name', 'season', 'gamesPlayed', 'avg', 'ops', 'homeRuns', 'runs', 'totalBases', 'rbi', 'babip']]
ohtani_df_comp
# Out:
#                name season gamesPlayed   avg    ops homeRuns runs totalBases  \
# 0  Ronald Acuna Jr.   2023         159  .337  1.012       41  149        383
# 1     Shohei Ohtani   2023         135  .304  1.066       44  102        325
# 2       Aaron Judge   2022         157  .311  1.111       62  133        391
# 3     Shohei Ohtani   2021         158  .257   .964       46  103        318
# 5   Freddie Freeman   2020          60  .341  1.102       13   51        137
# 6        Mike Trout   2019         134  .291  1.083       45  110        303
# 7      Mookie Betts   2018         136  .346  1.078       32  129        333
#
#    rbi babip
# 0  106  .338
# 1   95  .342
# 2  131  .340
# 3  100  .303
# 5   53  .366
# 6  104  .298
# 7   80  .368
